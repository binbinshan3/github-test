# %% [markdown]
# mathematica 实用小技巧
# ==
# - 对可行域的限定可以用&&来连接，向下图这样
#   ![image.png](attachment:a1facd7b-9b65-4f3d-af8e-8fedc4339b8e.png)
#
# - 可以用以下方法进行复制，避免反复输入的麻烦
# ![image.png](attachment:6b4113a6-d106-4c78-8cb4-7c789918c715.png)
#
# - 判断可行域
# ![image.png](attachment:eda81911-b150-47cc-8e74-55fa84237e21.png)
# ![image.png](attachment:bf7e7fa8-d8b9-47b3-ad84-753ee2495d6f.png)
#
#
# - 判断系数
# ![image.png](attachment:6897be93-79ec-47b0-b399-b1f5d34faaa1.png)
